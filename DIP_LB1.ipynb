# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
image=cv2.imread('/content/rgb.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b31c9706cd1a> in <cell line: 1>()
# ----> 1 image=cv2.imread('/content/rgb.jpg')
#
# NameError: name 'cv2' is not defined

# %%
image
# Out:
# array([[[213, 213, 213],
#         [213, 213, 213],
#         [213, 213, 213],
#         ...,
#         [213, 213, 213],
#         [213, 213, 213],
#         [213, 213, 213]],
#
#        [[213, 213, 213],
#         [213, 213, 213],
#         [213, 213, 213],
#         ...,
#         [213, 213, 213],
#         [213, 213, 213],
#         [213, 213, 213]],
#
#        [[213, 213, 213],
#         [213, 213, 213],
#         [213, 213, 213],
#         ...,
#         [213, 213, 213],
#         [213, 213, 213],
#         [213, 213, 213]],
#
#        ...,
#
#        [[213, 213, 213],
#         [213, 213, 213],
#         [213, 213, 213],
#         ...,
#         [213, 213, 213],
#         [213, 213, 213],
#         [213, 213, 213]],
#
#        [[213, 213, 213],
#         [213, 213, 213],
#         [213, 213, 213],
#         ...,
#         [213, 213, 213],
#         [213, 213, 213],
#         [213, 213, 213]],
#
#        [[213, 213, 213],
#         [213, 213, 213],
#         [213, 213, 213],
# ...

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=246x246 at 0x7F7E8877AE50>

# %%
plt.imshow(image)

# %%
image_gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
image_gray
# Out:
# array([[213, 213, 213, ..., 213, 213, 213],
#        [213, 213, 213, ..., 213, 213, 213],
#        [213, 213, 213, ..., 213, 213, 213],
#        ...,
#        [213, 213, 213, ..., 213, 213, 213],
#        [213, 213, 213, ..., 213, 213, 213],
#        [213, 213, 213, ..., 213, 213, 213]], dtype=uint8)

# %%
cv2_imshow(image_gray)
# Out:
# <PIL.Image.Image image mode=L size=246x246 at 0x7F7E884A0940>

# %%
plt.imshow(image_gray)

# %%
bnxc=plt.imshow(image_gray,cmap='gray') # 0,1 mapping

# %%
plt.imshow(image_gray,cmap='gray',vmin=0,vmax=255)

# %%
image_gray.ndim
# Out:
# 2

# %%
image_hsv=cv2.cvtColor(image,cv2.COLOR_BGR2HSV)

# %%
image_hsv
# Out:
# array([[[  0,   0, 213],
#         [  0,   0, 213],
#         [  0,   0, 213],
#         ...,
#         [  0,   0, 213],
#         [  0,   0, 213],
#         [  0,   0, 213]],
#
#        [[  0,   0, 213],
#         [  0,   0, 213],
#         [  0,   0, 213],
#         ...,
#         [  0,   0, 213],
#         [  0,   0, 213],
#         [  0,   0, 213]],
#
#        [[  0,   0, 213],
#         [  0,   0, 213],
#         [  0,   0, 213],
#         ...,
#         [  0,   0, 213],
#         [  0,   0, 213],
#         [  0,   0, 213]],
#
#        ...,
#
#        [[  0,   0, 213],
#         [  0,   0, 213],
#         [  0,   0, 213],
#         ...,
#         [  0,   0, 213],
#         [  0,   0, 213],
#         [  0,   0, 213]],
#
#        [[  0,   0, 213],
#         [  0,   0, 213],
#         [  0,   0, 213],
#         ...,
#         [  0,   0, 213],
#         [  0,   0, 213],
#         [  0,   0, 213]],
#
#        [[  0,   0, 213],
#         [  0,   0, 213],
#         [  0,   0, 213],
# ...

# %%
cv2_imshow(image_hsv)
# Out:
# <PIL.Image.Image image mode=RGB size=246x246 at 0x7F7E8878C7F0>

# %%
plt.imshow(image_hsv)

# %%
image_rgb=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
cv2_imshow(image_rgb)
# Out:
# <PIL.Image.Image image mode=RGB size=246x246 at 0x7F7E7D618E80>

# %%
plt.imshow(image_rgb)

# %%
print('Height ,Weight,Num of Channel ',image.shape)
# Out:
# Height ,Weight,Num of Channel  (246, 246, 3)

# %%
print("Total Pixel",image.size)
# Out:
# Total Pixel 181548

# %%
246*246*3
# Out:
# 181548

# %%
print("Dimention",image.ndim)
# Out:
# Dimention 3

# %%
b,g,r=cv2.split(image)

# %%
b
# Out:
# array([[213, 213, 213, ..., 213, 213, 213],
#        [213, 213, 213, ..., 213, 213, 213],
#        [213, 213, 213, ..., 213, 213, 213],
#        ...,
#        [213, 213, 213, ..., 213, 213, 213],
#        [213, 213, 213, ..., 213, 213, 213],
#        [213, 213, 213, ..., 213, 213, 213]], dtype=uint8)

# %%
g
# Out:
# array([[213, 213, 213, ..., 213, 213, 213],
#        [213, 213, 213, ..., 213, 213, 213],
#        [213, 213, 213, ..., 213, 213, 213],
#        ...,
#        [213, 213, 213, ..., 213, 213, 213],
#        [213, 213, 213, ..., 213, 213, 213],
#        [213, 213, 213, ..., 213, 213, 213]], dtype=uint8)

# %%
r
# Out:
# array([[213, 213, 213, ..., 213, 213, 213],
#        [213, 213, 213, ..., 213, 213, 213],
#        [213, 213, 213, ..., 213, 213, 213],
#        ...,
#        [213, 213, 213, ..., 213, 213, 213],
#        [213, 213, 213, ..., 213, 213, 213],
#        [213, 213, 213, ..., 213, 213, 213]], dtype=uint8)

# %%
rgb_image=cv2.merge((r,g,b))

# %%
num_of_blue_pixel=cv2.countNonZero(b)
print(num_of_blue_pixel)
# Out:
# 55353

# %%
num_of_green_pixel=cv2.countNonZero(g)
print(num_of_green_pixel)
# Out:
# 55276

# %%
num_of_red_pixel=cv2.countNonZero(r)
print(num_of_red_pixel)
# Out:
# 55672

# %%
55353+55672+55276
# Out:
# 166301

# %%
181548-166301
# Out:
# 15247

# %%
figure1=plt.figure(figsize=(20,10)) # weight,height 10 inch ,8 inch
ax1=figure1.add_subplot(151) #row,col,pos
ax2=figure1.add_subplot(152)
ax3=figure1.add_subplot(153)
ax4=figure1.add_subplot(154)
ax5=figure1.add_subplot(155)
ax1.imshow(image)
ax2.imshow(rgb_image)
ax3.imshow(r,cmap='gray',vmin=0,vmax=255)   #red pixel 255 others 0
ax4.imshow(g,cmap='gray',vmin=0,vmax=255)   #green pixel 255 others 0
ax5.imshow(b,cmap='gray',vmin=0,vmax=255)   #blue pixel 255 others 0

# %%
red=image[:,:,2]  # BGR  indx 0,1,2
green=image[:,:,1]
blue=image[:,:,0]

# %%
figure1=plt.figure(figsize=(20,10)) # weight,height 10 inch ,8 inch
ax1=figure1.add_subplot(151) #row,col,pos
ax2=figure1.add_subplot(152)
ax3=figure1.add_subplot(153)
ax4=figure1.add_subplot(154)
ax5=figure1.add_subplot(155)
ax1.imshow(image)
ax2.imshow(rgb_image)
ax3.imshow(red,cmap='gray',vmin=0,vmax=255)   #red pixel 255 others 0
ax4.imshow(green,cmap='gray',vmin=0,vmax=255)   #green pixel 255 others 0
ax5.imshow(blue,cmap='gray',vmin=0,vmax=255)   #blue pixel 255 others 0

# %%
figure2,ax=plt.subplots(1,3,figsize=(12,12)) #fig, axs = plt.subplots(2, 2, figsize=(15, 15))
ax[0].set_title('Red channel')
ax[0].imshow(red,cmap='gray',vmin=0,vmax=255)   #red pixel 255 others 0
ax[1].imshow(green,cmap='gray',vmin=0,vmax=255) 
ax[2].imshow(blue,cmap='gray',vmin=0,vmax=255)
